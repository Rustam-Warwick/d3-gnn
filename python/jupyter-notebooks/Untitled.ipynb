# %%
import sys

sys.path.append('/home/rustambaku13/Documents/Warwick/flink-streaming-gnn/python')

# %%
import jax
from flax.linen import relu, softmax, sigmoid, Module
from nn.jax.multi_layer_dense import MultiLayerDense
import jax.numpy as jnp
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Preprocessing

# %%
edges = pd.read_csv("../dataset/cora/edges.csv", header=None, names=["src", "dest"] )
vertices = pd.read_csv("../dataset/cora/group-edges.csv", header=None, names=['vertex', "label"])

unique_features = vertices.label.unique()
one_hot_features = jnp.eye(unique_features.shape[0])
label_feature_map = {k:one_hot_features[i] for i,k in enumerate(unique_features)}
vertices['feature'] = vertices.label.map(lambda x: label_feature_map[x])
vertices['train'] = np.random.rand(vertices.shape[0]) < 0.2
vertices['feature_train'] = vertices.label.map(lambda x: label_feature_map[x])
vertex_index_map = {vertex: index for (index,vertex) in enumerate(vertices.vertex.values)}

edge_list = jnp.vstack(edges.apply(lambda x: [vertex_index_map[x.src], vertex_index_map[x.dest]], axis=1))
fea

# %%
vertices['feature'] && vertices['train']
# Out:
#   File "<ipython-input-105-cb73e4df1045>", line 1
#     vertices['feature'] && vertices['train']
#                          ^
# SyntaxError: invalid syntax

# %%
jnp.vstack(list(vertices.feature.values)) & vertices.train.values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/miniconda3/envs/flink/lib/python3.8/site-packages/jax/_src/util.py in wrapper(*args, **kwargs)
#     201       else:
# --> 202         return cached(config._trace_context(), *args, **kwargs)
#     203
#
# ~/miniconda3/envs/flink/lib/python3.8/site-packages/jax/_src/util.py in cached(_, *args, **kwargs)
#     194     def cached(_, *args, **kwargs):
# --> 195       return f(*args, **kwargs)
#     196
#
# ~/miniconda3/envs/flink/lib/python3.8/site-packages/jax/_src/lax/lax.py in _broadcast_shapes_cached(*shapes)
#     112 def _broadcast_shapes_cached(*shapes: Tuple[int, ...]) -> Tuple[int, ...]:
# --> 113   return _broadcast_shapes_uncached(*shapes)
#     114
#
# ~/miniconda3/envs/flink/lib/python3.8/site-packages/jax/_src/lax/lax.py in _broadcast_shapes_uncached(*shapes)
#     127   if result_shape is None:
# --> 128     raise ValueError("Incompatible shapes for broadcasting: {}"
#     129                      .format(tuple(shape_list)))
#
# ValueError: Incompatible shapes for broadcasting: ((2708, 7), (1, 2708))
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-770570d0547f> in <module>
# ----> 1 jnp.vstack(list(vertices.feature.values)) & vertices.train.values
#
# ~/miniconda3/envs/flink/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in deferring_binary_op(self, other)
#    6713     if not isinstance(other, _accepted_binop_types):
#    6714       return NotImplemented
# -> 6715     return binary_op(self, other)
#    6716   return deferring_binary_op
#    6717
#
#     [... skipping hidden 14 frame]
#
# ~/miniconda3/envs/flink/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in <lambda>(x1, x2)
#     687     fn = lambda x1, x2: lax_fn(*_promote_args_inexact(numpy_fn.__name__, x1, x2))
#     688   else:
# --> 689     fn = lambda x1, x2: lax_fn(*_promote_args(numpy_fn.__name__, x1, x2))
#     690   fn = jit(fn, inline=True)
#     691   if lax_doc:
#
# ~/miniconda3/envs/flink/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _promote_args(fun_name, *args)
#     577   _check_arraylike(fun_name, *args)
#     578   _check_no_float0s(fun_name, *args)
# --> 579   return _promote_shapes(fun_name, *_promote_dtypes(*args))
#     580
#     581 def _promote_args_inexact(fun_name, *args):
#
# ~/miniconda3/envs/flink/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _promote_shapes(fun_name, *args)
#     491       if config.jax_numpy_rank_promotion != "allow":
#     492         _rank_promotion_warning_or_error(fun_name, shapes)
# --> 493       result_shape = lax.broadcast_shapes(*shapes)
#     494       return [broadcast_to(arg, result_shape) for arg, shp in zip(args, shapes)]
#     495
#
#     [... skipping hidden 1 frame]
#
# ~/miniconda3/envs/flink/lib/python3.8/site-packages/jax/_src/lax/lax.py in _broadcast_shapes_uncached(*shapes)
#     126   result_shape = _try_broadcast_shapes(shape_list)
#     127   if result_shape is None:
# --> 128     raise ValueError("Incompatible shapes for broadcasting: {}"
#     129                      .format(tuple(shape_list)))
#     130   return result_shape
#
# ValueError: Incompatible shapes for broadcasting: ((2708, 7), (1, 2708))

# %%
vertex_index_map
# Out:
# {1000012: 0,
#  100197: 1,
#  100701: 2,
#  100935: 3,
#  100961: 4,
#  101143: 5,
#  101145: 6,
#  101261: 7,
#  101263: 8,
#  101660: 9,
#  101662: 10,
#  10169: 11,
#  10174: 12,
#  10177: 13,
#  101811: 14,
#  10183: 15,
#  10186: 16,
#  102061: 17,
#  1022969: 18,
#  102406: 19,
#  1026: 20,
#  102879: 21,
#  102884: 22,
#  102938: 23,
#  102939: 24,
#  1031453: 25,
#  1033: 26,
#  1034: 27,
#  103430: 28,
#  103482: 29,
#  1035: 30,
#  103515: 31,
#  103528: 32,
#  103529: 33,
#  103531: 34,
#  103537: 35,
#  103543: 36,
#  10430: 37,
#  10435: 38,
#  104840: 39,
#  105057: 40,
#  1050679: 41,
#  10531: 42,
#  105856: 43,
#  105865: 44,
#  105899: 45,
#  1059953: 46,
#  1061127: 47,
#  1063773: 48,
#  106590: 49,
#  107177: 50,
#  1071981: 51,
#  107251: 52,
#  107252: 53,
#  107569: 54,
#  10793: 55,
#  10796: 56,
#  10798: 57,
#  108047: 58,
#  108962: 59,
#  108963: 60,
#  108974: 61,
#  108983: 62,
#  109323: 63,
#  1095507: 64,
#  10981: 65,
#  110041: 66,
#  110162: 67,
#  110163: 68,
#  110164: 69,
#  1102364: 70,
#  1102400: 71,
#  1102407: 72,
#  1102442: 73,
#  1102548: 74,
#  1102550: 75,
#  1102567: 76,
#  1102625: 77,
#  1102646: 78,
#  1102751: 79,
#  1102761: 80,
#  1102794: 81,
#  1102850: 82,
#  1102873: 83,
#  1103016: 84,
#  1103031: 85,
#  1103038: 86,
#  1103162: 87,
#  1103315: 88,
#  1103383: 89,
#  1103394: 90,
#  1103499: 91,
#  1103610: 92,
#  1103676: 93,
#  1103737: 94,
#  1103960: 95,
#  1103969: 96,
#  1103979: 97,
#  1103985: 98,
#  1104007: 99,
#  1104031: 100,
#  1104055: 101,
#  1104182: 102,
#  1104191: 103,
#  1104258: 104,
#  1104261: 105,
#  1104300: 106,
#  1104379: 107,
#  1104435: 108,
#  1104449: 109,
#  1104495: 110,
#  1104647: 111,
#  1104749: 112,
#  1104769: 113,
#  1104787: 114,
#  1104809: 115,
#  1104851: 116,
#  1104946: 117,
#  1104999: 118,
#  1105011: 119,
#  1105033: 120,
#  1105062: 121,
#  1105116: 122,
#  1105148: 123,
#  1105221: 124,
#  1105231: 125,
#  1105344: 126,
#  1105360: 127,
#  1105394: 128,
#  1105428: 129,
#  1105433: 130,
#  1105450: 131,
#  1105505: 132,
#  1105530: 133,
#  1105531: 134,
#  1105574: 135,
#  1105603: 136,
#  1105622: 137,
#  1105672: 138,
#  1105698: 139,
#  1105718: 140,
#  1105764: 141,
#  1105810: 142,
#  1105877: 143,
#  1105887: 144,
#  1105932: 145,
#  1106052: 146,
#  1106103: 147,
#  1106112: 148,
#  1106172: 149,
#  1106236: 150,
#  1106287: 151,
#  1106298: 152,
#  1106330: 153,
#  1106370: 154,
#  1106388: 155,
#  1106401: 156,
#  1106406: 157,
#  1106418: 158,
#  1106492: 159,
#  1106546: 160,
#  1106547: 161,
#  1106568: 162,
#  1106630: 163,
#  1106671: 164,
#  1106764: 165,
#  1106771: 166,
#  1106789: 167,
#  1106849: 168,
#  1106854: 169,
#  1106966: 170,
#  1107010: 171,
#  1107041: 172,
#  1107062: 173,
#  1107067: 174,
#  1107095: 175,
#  1107136: 176,
#  1107140: 177,
#  1107171: 178,
#  1107215: 179,
#  1107312: 180,
#  1107319: 181,
#  1107325: 182,
#  1107355: 183,
#  1107367: 184,
#  1107385: 185,
#  1107418: 186,
#  1107455: 187,
#  1107558: 188,
#  1107567: 189,
#  1107572: 190,
#  1107674: 191,
#  1107728: 192,
#  1107808: 193,
#  1107861: 194,
#  1108050: 195,
#  1108167: 196,
#  1108169: 197,
#  1108175: 198,
#  1108209: 199,
#  1108258: 200,
#  1108267: 201,
#  1108329: 202,
#  1108363: 203,
#  1108389: 204,
#  1108551: 205,
#  1108570: 206,
#  1108597: 207,
#  1108656: 208,
#  1108728: 209,
#  1108834: 210,
#  1108841: 211,
#  1109017: 212,
#  1109185: 213,
#  1109199: 214,
#  1109208: 215,
#  11093: 216,
#  1109392: 217,
#  1109439: 218,
#  1109542: 219,
#  1109566: 220,
#  1109581: 221,
#  1109830: 222,
#  1109873: 223,
#  1109891: 224,
#  1109957: 225,
#  1110000: 226,
#  1110024: 227,
#  1110028: 228,
#  1110209: 229,
#  1110256: 230,
#  1110390: 231,
#  1110426: 232,
#  1110438: 233,
#  1110494: 234,
#  1110515: 235,
#  1110520: 236,
#  1110531: 237,
#  1110546: 238,
#  1110563: 239,
#  1110579: 240,
#  1110628: 241,
#  1110768: 242,
#  1110947: 243,
#  1110950: 244,
#  1110998: 245,
#  1111052: 246,
#  1111186: 247,
#  1111230: 248,
#  1111240: 249,
#  1111265: 250,
#  1111304: 251,
#  1111614: 252,
#  1111733: 253,
#  1111788: 254,
#  1111899: 255,
#  1111978: 256,
#  1112026: 257,
#  1112071: 258,
#  1112075: 259,
#  1112099: 260,
#  1112106: 261,
#  1112194: 262,
#  1112319: 263,
#  1112369: 264,
#  1112417: 265,
#  1112426: 266,
#  1112574: 267,
#  1112650: 268,
#  1112665: 269,
#  1112686: 270,
#  1112723: 271,
#  1112767: 272,
#  1112911: 273,
#  1112929: 274,
#  1113035: 275,
#  1113084: 276,
#  1113182: 277,
#  1113438: 278,
#  1113459: 279,
#  1113534: 280,
#  1113541: 281,
#  1113551: 282,
#  1113614: 283,
#  1113739: 284,
#  1113742: 285,
#  1113828: 286,
#  1113831: 287,
#  1113852: 288,
#  1113926: 289,
#  1113934: 290,
#  1113995: 291,
#  1114118: 292,
#  1114125: 293,
#  1114153: 294,
#  1114184: 295,
#  1114192: 296,
#  1114222: 297,
#  1114239: 298,
#  1114331: 299,
#  1114336: 300,
#  1114352: 301,
#  1114364: 302,
#  1114388: 303,
#  1114398: 304,
#  1114442: 305,
#  1114502: 306,
#  1114512: 307,
#  1114526: 308,
#  1114605: 309,
#  1114629: 310,
#  1114664: 311,
#  1114777: 312,
#  11148: 313,
#  1114838: 314,
#  1114864: 315,
#  1114992: 316,
#  1115166: 317,
#  1115291: 318,
#  1115375: 319,
#  1115456: 320,
#  1115471: 321,
#  1115670: 322,
#  1115677: 323,
#  1115701: 324,
#  1115790: 325,
#  1115886: 326,
#  1115959: 327,
#  1116044: 328,
#  1116146: 329,
#  1116181: 330,
#  1116268: 331,
#  1116328: 332,
#  1116336: 333,
#  1116347: 334,
#  1116397: 335,
#  1116410: 336,
#  1116530: 337,
#  1116569: 338,
#  1116594: 339,
#  1116629: 340,
#  111676: 341,
#  1116835: 342,
#  1116839: 343,
#  1116842: 344,
#  1116922: 345,
#  1116974: 346,
#  1117049: 347,
#  1117089: 348,
#  1117184: 349,
#  1117219: 350,
#  1117249: 351,
#  1117348: 352,
#  1117476: 353,
#  1117501: 354,
#  1117618: 355,
#  1117653: 356,
#  111770: 357,
#  1117760: 358,
#  1117786: 359,
#  1117833: 360,
#  1117920: 361,
#  1117942: 362,
#  1118017: 363,
#  1118083: 364,
#  1118092: 365,
#  1118120: 366,
#  1118209: 367,
#  1118245: 368,
#  1118286: 369,
#  1118302: 370,
#  1118332: 371,
#  1118347: 372,
#  1118388: 373,
#  1118546: 374,
#  1118658: 375,
#  111866: 376,
#  1118764: 377,
#  1118823: 378,
#  1118848: 379,
#  1119004: 380,
#  1119078: 381,
#  1119140: 382,
#  1119178: 383,
#  1119180: 384,
#  1119211: 385,
#  1119216: 386,
#  1119295: 387,
#  1119471: 388,
#  1119505: 389,
#  1119623: 390,
#  1119654: 391,
#  1119671: 392,
#  1119708: 393,
#  1119742: 394,
#  1119751: 395,
#  1119987: 396,
#  1120019: 397,
#  1120020: 398,
#  1120049: 399,
#  1120059: 400,
#  1120084: 401,
#  1120138: 402,
#  1120169: 403,
#  1120170: 404,
#  1120197: 405,
#  1120211: 406,
#  1120252: 407,
#  1120431: 408,
#  1120444: 409,
#  1120563: 410,
#  1120643: 411,
#  1120650: 412,
#  1120713: 413,
#  1120731: 414,
#  1120777: 415,
#  1120786: 416,
#  1120858: 417,
#  1120866: 418,
#  1120880: 419,
#  1120962: 420,
#  112099: 421,
#  1121057: 422,
#  1121063: 423,
#  1121176: 424,
#  1121254: 425,
#  1121313: 426,
#  1121398: 427,
#  1121459: 428,
#  1121537: 429,
#  1121569: 430,
#  1121603: 431,
#  1121659: 432,
#  1121739: 433,
#  1121867: 434,
#  1122304: 435,
#  1122425: 436,
#  1122460: 437,
#  1122574: 438,
#  1122580: 439,
#  1122642: 440,
#  1122704: 441,
#  1123068: 442,
#  1123087: 443,
#  1123093: 444,
#  1123188: 445,
#  1123215: 446,
#  1123239: 447,
#  1123493: 448,
#  1123530: 449,
#  1123553: 450,
#  1123576: 451,
#  1123689: 452,
#  1123756: 453,
#  112378: 454,
#  1123867: 455,
#  1123926: 456,
#  1123991: 457,
#  1124837: 458,
#  1124844: 459,
#  1125082: 460,
#  1125092: 461,
#  1125258: 462,
#  1125386: 463,
#  1125393: 464,
#  1125402: 465,
#  1125467: 466,
#  1125469: 467,
#  1125492: 468,
#  1125597: 469,
#  1125895: 470,
#  1125906: 471,
#  1125909: 472,
#  1125944: 473,
#  1125953: 474,
#  1125992: 475,
#  1125993: 476,
#  1126011: 477,
#  1126012: 478,
#  1126029: 479,
#  1126037: 480,
#  1126044: 481,
#  1126050: 482,
#  1126315: 483,
#  1126350: 484,
#  1126503: 485,
#  1127430: 486,
#  1127530: 487,
#  1127541: 488,
#  1127551: 489,
#  1127558: 490,
#  1127566: 491,
#  1127619: 492,
#  1127657: 493,
#  1127810: 494,
#  1127812: 495,
#  1127851: 496,
#  1127863: 497,
#  112787: 498,
#  1127913: 499,
#  112813: 500,
#  1128151: 501,
#  1128198: 502,
#  1128201: 503,
#  1128204: 504,
#  1128208: 505,
#  1128227: 506,
#  1128256: 507,
#  1128267: 508,
#  1128291: 509,
#  1128314: 510,
#  1128319: 511,
#  1128369: 512,
#  1128407: 513,
#  1128425: 514,
#  1128430: 515,
#  1128437: 516,
#  1128453: 517,
#  1128531: 518,
#  1128536: 519,
#  1128542: 520,
#  1128839: 521,
#  1128846: 522,
#  1128853: 523,
#  1128856: 524,
#  1128868: 525,
#  1128881: 526,
#  1128927: 527,
#  1128935: 528,
#  1128943: 529,
#  1128945: 530,
#  1128946: 531,
#  1128959: 532,
#  1128974: 533,
#  1128975: 534,
#  1128977: 535,
#  1128978: 536,
#  1128982: 537,
#  1128985: 538,
#  1128990: 539,
#  1128997: 540,
#  1129015: 541,
#  1129018: 542,
#  1129021: 543,
#  1129027: 544,
#  1129040: 545,
#  1129096: 546,
#  1129106: 547,
#  1129111: 548,
#  1129208: 549,
#  1129243: 550,
#  1129367: 551,
#  1129368: 552,
#  1129369: 553,
#  1129442: 554,
#  1129443: 555,
#  1129494: 556,
#  1129518: 557,
#  1129570: 558,
#  1129572: 559,
#  1129573: 560,
#  1129608: 561,
#  1129610: 562,
#  1129621: 563,
#  1129629: 564,
#  1129683: 565,
#  1129778: 566,
#  1129798: 567,
#  1129835: 568,
#  1129907: 569,
#  1129994: 570,
#  1130069: 571,
#  1130080: 572,
#  1130243: 573,
#  1130356: 574,
#  1130454: 575,
#  1130539: 576,
#  1130567: 577,
#  1130568: 578,
#  1130586: 579,
#  1130600: 580,
#  1130634: 581,
#  1130637: 582,
#  1130653: 583,
#  1130657: 584,
#  1130676: 585,
#  1130678: 586,
#  1130680: 587,
#  1130780: 588,
#  1130808: 589,
#  1130847: 590,
#  1130856: 591,
#  1130915: 592,
#  1130927: 593,
#  1130929: 594,
#  1130931: 595,
#  1130934: 596,
#  1131116: 597,
#  1131137: 598,
#  1131149: 599,
#  1131150: 600,
#  1131163: 601,
#  1131164: 602,
#  1131165: 603,
#  1131167: 604,
#  1131172: 605,
#  1131180: 606,
#  1131184: 607,
#  1131189: 608,
#  1131192: 609,
#  1131195: 610,
#  1131198: 611,
#  1131223: 612,
#  1131230: 613,
#  1131236: 614,
#  1131257: 615,
#  1131258: 616,
#  1131266: 617,
#  1131267: 618,
#  1131270: 619,
#  1131274: 620,
#  1131277: 621,
#  1131300: 622,
#  1131301: 623,
#  1131305: 624,
#  1131312: 625,
#  1131314: 626,
#  1131330: 627,
#  1131334: 628,
#  1131335: 629,
#  1131345: 630,
#  1131348: 631,
#  1131359: 632,
#  1131360: 633,
#  1131374: 634,
#  1131414: 635,
#  1131420: 636,
#  1131421: 637,
#  1131464: 638,
#  1131466: 639,
#  1131471: 640,
#  1131549: 641,
#  1131550: 642,
#  1131557: 643,
#  1131565: 644,
#  1131607: 645,
#  1131611: 646,
#  1131634: 647,
#  1131639: 648,
#  1131647: 649,
#  1131719: 650,
#  1131728: 651,
#  1131734: 652,
#  1131741: 653,
#  1131745: 654,
#  1131748: 655,
#  1131752: 656,
#  1131754: 657,
#  1131828: 658,
#  1132073: 659,
#  1132083: 660,
#  1132157: 661,
#  1132285: 662,
#  1132385: 663,
#  1132406: 664,
#  1132416: 665,
#  1132418: 666,
#  1132434: 667,
#  1132443: 668,
#  1132459: 669,
#  1132461: 670,
#  1132486: 671,
#  11325: 672,
#  1132505: 673,
#  11326: 674,
#  1132706: 675,
#  1132731: 676,
#  1132809: 677,
#  1132815: 678,
#  1132857: 679,
#  1132864: 680,
#  1132887: 681,
#  1132922: 682,
#  1132948: 683,
#  1132968: 684,
#  1133004: 685,
#  1133008: 686,
#  1133010: 687,
#  1133028: 688,
#  1133047: 689,
#  1133196: 690,
#  1133338: 691,
#  1133390: 692,
#  1133417: 693,
#  1133428: 694,
#  1133469: 695,
#  11335: 696,
#  11337: 697,
#  1133846: 698,
#  11339: 699,
#  1133930: 700,
#  1134022: 701,
#  1134031: 702,
#  1134056: 703,
#  1134197: 704,
#  11342: 705,
#  1134320: 706,
#  1134346: 707,
#  1134348: 708,
#  1134865: 709,
#  1135082: 710,
#  1135108: 711,
#  1135115: 712,
#  1135122: 713,
#  1135125: 714,
#  1135137: 715,
#  1135345: 716,
#  1135358: 717,
#  1135368: 718,
#  1135455: 719,
#  1135589: 720,
#  1135746: 721,
#  1135750: 722,
#  1135894: 723,
#  1135899: 724,
#  1135955: 725,
#  1136040: 726,
#  1136110: 727,
#  1136310: 728,
#  1136342: 729,
#  1136393: 730,
#  1136397: 731,
#  1136422: 732,
#  1136442: 733,
#  1136446: 734,
#  1136447: 735,
#  1136449: 736,
#  1136631: 737,
#  1136634: 738,
#  1136791: 739,
#  1136814: 740,
#  1137140: 741,
#  1137466: 742,
#  1138027: 743,
#  1138043: 744,
#  1138091: 745,
#  1138619: 746,
#  1138755: 747,
#  1138968: 748,
#  1138970: 749,
#  1139009: 750,
#  1139195: 751,
#  1139928: 752,
#  114: 753,
#  1140040: 754,
#  1140230: 755,
#  1140231: 756,
#  1140289: 757,
#  1140543: 758,
#  1140547: 759,
#  1140548: 760,
#  114189: 761,
#  114308: 762,
#  114966: 763,
#  115188: 764,
#  1152075: 765,
#  1152143: 766,
#  1152150: 767,
#  1152162: 768,
#  1152179: 769,
#  1152194: 770,
#  1152244: 771,
#  1152259: 772,
#  1152272: 773,
#  1152277: 774,
#  1152290: 775,
#  1152307: 776,
#  1152308: 777,
#  1152358: 778,
#  1152379: 779,
#  1152394: 780,
#  1152421: 781,
#  1152436: 782,
#  1152448: 783,
#  1152490: 784,
#  1152508: 785,
#  1152564: 786,
#  1152569: 787,
#  1152633: 788,
#  1152663: 789,
#  1152673: 790,
#  1152676: 791,
#  1152711: 792,
#  1152714: 793,
#  1152740: 794,
#  1152761: 795,
#  1152821: 796,
#  1152858: 797,
#  1152859: 798,
#  1152896: 799,
#  1152904: 800,
#  1152910: 801,
#  1152917: 802,
#  1152944: 803,
#  1152958: 804,
#  1152959: 805,
#  1152975: 806,
#  1152991: 807,
#  1153003: 808,
#  1153014: 809,
#  1153024: 810,
#  1153031: 811,
#  1153056: 812,
#  1153064: 813,
#  1153065: 814,
#  1153091: 815,
#  1153097: 816,
#  1153101: 817,
#  1153106: 818,
#  1153148: 819,
#  1153150: 820,
#  1153160: 821,
#  1153166: 822,
#  1153169: 823,
#  1153183: 824,
#  1153195: 825,
#  1153254: 826,
#  1153262: 827,
#  1153264: 828,
#  1153275: 829,
#  1153280: 830,
#  1153287: 831,
#  1153577: 832,
#  1153703: 833,
#  1153724: 834,
#  1153728: 835,
#  1153736: 836,
#  1153784: 837,
#  1153786: 838,
#  1153811: 839,
#  1153816: 840,
#  1153853: 841,
#  1153860: 842,
#  1153861: 843,
#  1153866: 844,
#  1153877: 845,
#  1153879: 846,
#  1153889: 847,
#  1153891: 848,
#  1153896: 849,
#  1153897: 850,
#  1153899: 851,
#  1153900: 852,
#  1153922: 853,
#  1153933: 854,
#  1153942: 855,
#  1153943: 856,
#  1153945: 857,
#  1153946: 858,
#  1154012: 859,
#  1154042: 860,
#  1154068: 861,
#  1154071: 862,
#  1154074: 863,
#  1154076: 864,
#  1154103: 865,
#  1154123: 866,
#  1154124: 867,
#  1154169: 868,
#  1154173: 869,
#  1154176: 870,
#  1154229: 871,
#  1154230: 872,
#  1154232: 873,
#  1154233: 874,
#  1154251: 875,
#  1154276: 876,
#  1154459: 877,
#  1154500: 878,
#  1154520: 879,
#  1154524: 880,
#  1154525: 881,
#  1155073: 882,
#  116021: 883,
#  116081: 884,
#  116084: 885,
#  116087: 886,
#  116512: 887,
#  116528: 888,
#  116545: 889,
#  116552: 890,
#  116553: 891,
#  116790: 892,
#  117: 893,
#  117315: 894,
#  117316: 895,
#  117328: 896,
#  118079: 897,
#  118259: 898,
#  118260: 899,
#  118424: 900,
#  118435: 901,
#  118436: 902,
#  118558: 903,
#  118559: 904,
#  118682: 905,
#  118873: 906,
#  119686: 907,
#  119712: 908,
#  119761: 909,
#  119956: 910,
#  120013: 911,
#  120039: 912,
#  120084: 913,
#  120817: 914,
#  1213: 915,
#  12155: 916,
#  12158: 917,
#  12165: 918,
#  12169: 919,
#  121792: 920,
#  12182: 921,
#  12194: 922,
#  12195: 923,
#  12197: 924,
#  12198: 925,
#  12199: 926,
#  12210: 927,
#  12211: 928,
#  12238: 929,
#  12247: 930,
#  12275: 931,
#  12330: 932,
#  12337: 933,
#  12347: 934,
#  12350: 935,
#  123556: 936,
#  12359: 937,
#  1237: 938,
#  123825: 939,
#  124064: 940,
#  124224: 941,
#  124296: 942,
#  12439: 943,
#  1246: 944,
#  124734: 945,
#  124828: 946,
#  124952: 947,
#  12558: 948,
#  12576: 949,
#  126128: 950,
#  12631: 951,
#  12638: 952,
#  126793: 953,
#  126867: 954,
#  126868: 955,
#  126909: 956,
#  126912: 957,
#  126920: 958,
#  126926: 959,
#  126927: 960,
#  127033: 961,
#  1272: 962,
#  127940: 963,
#  128: 964,
#  128202: 965,
#  128203: 966,
#  128383: 967,
#  128540: 968,
#  129042: 969,
#  129045: 970,
#  129287: 971,
#  12946: 972,
#  129558: 973,
#  12960: 974,
#  129896: 975,
#  129897: 976,
#  130: 977,
#  13024: 978,
#  131042: 979,
#  131117: 980,
#  131122: 981,
#  131315: 982,
#  131317: 983,
#  131318: 984,
#  13136: 985,
#  13193: 986,
#  13195: 987,
#  13205: 988,
#  13208: 989,
#  13212: 990,
#  13213: 991,
#  13269: 992,
#  132806: 993,
#  132821: 994,
#  133550: 995,
#  133553: 996,
#  133563: 997,
#  133566: 998,
#  133567: 999,
#  ...}

# %% [markdown]
# ## Model Creation

# %%
class GNNLayer(Module):
    message: Module
    update: Module
    agg: str
    
    def __call__(self, vertex_features, edges):
